# %% [markdown]
# # Transkribus REST API Client

# %% [markdown]
# ## Basics I: Talking to a very simple API
# Playing around with a free and simple API is the best way to learn how to use the `requests` package. The Open Notify API for example provides information about the International Space Station.
#
# Where to get help:
# * documentation of this API: http://api.open-notify.org/
# * the `requests` package: https://docs.python-requests.org/en/master/
# * the `json` package: https://docs.python.org/3/library/json.html

# %%
""" List the astronauts that are currently on the ISS
    using the Open Notify API: http://api.open-notify.org/ """

import requests
import json

# Build the URL using the "astros.json" endpoint:
api_base_url = "http://api.open-notify.org/"
endpoint = "astros.json"
url = api_base_url + endpoint

# Make the request and store the response:
response = requests.get(url)

# Evaluate the response:
if response:
    try:
        json_response = response.json()
        print("The raw JSON response sent by the server:")
        print(json.dumps(json_response))   
        print("\nPeople on the ISS:")
        for astronaut in json_response['people']:
            if astronaut['craft'] == "ISS":
                print("– " + astronaut['name'])
    except:
        print(f"ERROR: Something went wrong. {response.content}")
else:
    print(f"ERROR: Something went wrong. HTTP status code: {response.status_code}")
# Out:
# The raw JSON response sent by the server:
# {"people": [{"name": "Mark Vande Hei", "craft": "ISS"}, {"name": "Oleg Novitskiy", "craft": "ISS"}, {"name": "Pyotr Dubrov", "craft": "ISS"}, {"name": "Thomas Pesquet", "craft": "ISS"}, {"name": "Megan McArthur", "craft": "ISS"}, {"name": "Shane Kimbrough", "craft": "ISS"}, {"name": "Akihiko Hoshide", "craft": "ISS"}, {"name": "Nie Haisheng", "craft": "Tiangong"}, {"name": "Liu Boming", "craft": "Tiangong"}, {"name": "Tang Hongbo", "craft": "Tiangong"}], "number": 10, "message": "success"}
#
# People on the ISS:
# – Mark Vande Hei
# – Oleg Novitskiy
# – Pyotr Dubrov
# – Thomas Pesquet
# – Megan McArthur
# – Shane Kimbrough
# – Akihiko Hoshide

# %% [markdown]
# ## Basics II: Talking to the Transkribus REST-API
# Using the same approach as above, we can access the Transkribus REST-API. First we have to log in, then we can access the endpoints, finally we have to log out.
#
# Where to get help:
# * the documentation of the Transkribus REST-API: https://readcoop.eu/transkribus/docu/rest-api/
# * a list of all available endpoints: https://transkribus.eu/TrpServer/Swadl/wadl.html
# * the `objectify` API of the `lxml` package: https://lxml.de/objectify.html

# %%
import requests
import sys
from lxml import objectify

# Define building blocks for the endpoints:
api_base_url = "https://transkribus.eu/TrpServer/rest/"
login_endpoint = "auth/login"
collections_endpoint = "collections/list"
logout_endpoint = "auth/logout"

# Log in:
## Prepare the payload for the POST request:
credentials = {'user': 'YOUR_USER_NAME',
               'pw': 'YOUR_PASSWORD'}
## Create the POST request (the requests package converts the credentials into JSON automatically):
response = requests.post(api_base_url + login_endpoint, data=credentials)

## Evaluate the response:
if response:
    r = objectify.fromstring(response.content)
    print(f"TRANSKRIBUS: User {r.firstname} {r.lastname} ({r.userId}) logged in successfully.")
    session_id = str(r.sessionId)
else:
    sys.exit("TRANSKRIBUS: Login failed.")

# Get the list of collections (using a GET request):
cookies = dict(JSESSIONID=session_id)
response = requests.get(api_base_url + collections_endpoint, cookies=cookies)
if response:
    collections = response.json()
    print("TRANSKRIBUS: Your collections:")
    for collection in collections:
        print(f"– {collection['colName']}, ({collection['nrOfDocuments']} documents)")
else:
    sys.exit("TRANSKRIBUS: Could not retrieve collections.")

# Log out (using a POST request):
response = requests.post(api_base_url + logout_endpoint, cookies=cookies)
if response:
    print("TRANSKRIBUS: Logged out successfully!")
else:
    sys.exit("TRANSKRIBUS: Logout failed.")
# Out:
# TRANSKRIBUS: User Markus Müller (XXXXX) logged in successfully.
# TRANSKRIBUS: Your collections:
# – XYZ@example.de Collection, (14 documents)
# – FerusAlpha, (24 documents)
# – FerusBeta, (8 documents)
# – FerusArchiv, (12 documents)
# – Transkribus Spellchecker Demo, (1 documents)
# TRANSKRIBUS: Logged out successfully!

# %% [markdown]
# # A custom Transkribus REST-API Client class
# You may have noticed that the code above is very repetetive: For example, in every step we use the same `response = requests.get` command. Therefore, it is more convenient to offload the repetetive code into reusable functions and wrap these functions in a class.

# %%
import requests
import json
from lxml import objectify, etree
from pprint import pprint

# %%
class Transkribus_Web():
    """ The Transkribus_Web class implements the communication with the 
        Transkribus REST API. 
        
        All available endpoints: https://transkribus.eu/TrpServer/Swadl/wadl.html
        Documentation: https://readcoop.eu/transkribus/docu/rest-api/
        Official TranskribusPyClient: https://github.com/Transkribus/TranskribusPyClient """
    
    def __init__(self, api_base_url="https://transkribus.eu/TrpServer/rest/"):
        self.cols = {}
        self.api_base_url = api_base_url
        self.session_id = False
        self.cache = False
    
    # Internal helper functions:
    
    def _url(self, endpoint):
        """ Helper function that returns a full URL for requests to the REST API, 
            i.e. the API base URL + the relative path of the endpoint. """
        
        return self.api_base_url + endpoint
    
    # Core functionality: login, logout, send GET requests
    
    def login(self, username, password):
        """ Performs a login and stores the SESSIONID in the "session_id" variable
            of this class. """
        
        credentials = {'user': username,
                       'pw': password}
        response = requests.post(self._url("auth/login"), data=credentials)
        if response:
            r = objectify.fromstring(response.content)
            print(f"TRANSKRIBUS: User {r.firstname} {r.lastname} ({r.userId}) logged in successfully.")
            self.session_id = str(r.sessionId)
            return str(r.sessionId)
        else:
            print("TRANSKRIBUS: Login failed. HTTP status:", response.status_code)
            return False
    
    def logout(self):
        """ Logs out and sets the "session_id" variable to False. """
        
        cookies = dict(JSESSIONID=self.session_id)
        response = requests.post(self._url("auth/logout"), cookies=cookies)
        if response:
            self.session_id = False
            print("TRANSKRIBUS: Logged out successfully.")
            return True
        else:
            print("TRANSKRIBUS: Logout failed. HTTP status:", response.status_code, response.content)
            return False

    def verify(self, username, password):
        """ Logs in and logs out to check whether the credentials
            are valid on the Transkribus server. 
            Returns True or False. """
        
        session_id = self.login(username, password)
        if session_id:
            self.logout(session_id)
            return True
        else: 
            return False        
        
    def request_endpoint(self, endpoint):
        """ Sends a GET request to a Transkribus API endpoint, the 
            "endpoint" argument being a relative path to the REST API endpoint

            Cf. the list of available endpoints:
            https://transkribus.eu/TrpServer/Swadl/wadl.html

            Depending on the content type (JSON or XML), 
            the function tries to decode the raw content of the response.
            It returns a json object or an "objectify" object (lxml). If
            the conversion fails the raw content is returned. """

        cookies = dict(JSESSIONID=self.session_id)
        
        response = requests.get(self._url(endpoint), cookies=cookies)

        if response:
            try:
                json = response.json()
                return json
            except:
                try:
                    xml = objectify.fromstring(response.content)
                    return xml
                except:
                    return response.content  # fallback option if the server returns just text
        else:
            print(f'TRANSKRIBUS: ERROR when requesting "{endpoint}". HTTP status:', response.status_code)
            return False
    
    # Convenience functions to query certain endpoints: 
    
    def get_collections(self):
        """ Get the metadata of the owner's collections. 
            Returns a dict if successful or False if not. """
        
        endpoint = "collections/list"
        collections = self.request_endpoint(endpoint)
        return collections if collections else False
    
    def get_documents_in_collection(self, colId):
        """ Get the metadata of a collection. 
            Returns a dict if successful or False if not.
            
            colId -- collection ID in Transkribus (int) """
        
        endpoint = f"collections/{colId}/list"
        documents = self.request_endpoint(endpoint)
        return documents if documents else False

    def get_pages_in_document(self, colId, docId):
        """ Get the basic metadata of the pages in a document. 
            Returns a dict if successful or False if not.
           
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) """
        
        endpoint = f"collections/{colId}/{docId}/pages"
        pages = self.request_endpoint(endpoint)
        return pages if pages else False
        
    def get_page_xml(self, colId, docId, pageNr):
        """ Get the XML content of a page. 
            Returns an "objectify" object (lxml) or False if not successful. 
            
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) 
            
            The returned object X has two attributes: X.Metadata and X.Page. 
            X.Page is empty if there are no transcripts yet. 
            If there exists a transcription X.Page has further attributes
            (i and j are list indices counting from 0):
            
            X.Page.Metadata
                  .ReadingOrder
                  .values()   -> list containing imgFileName, width (px), height (px)
                  .TextRegion[i].Coords.attrib['points']               -> coordinates of the whole text region (1)
                                .TextEquiv.Unicode                     -> utf-8 string of the transcription of the whole text region
                                .TextLine[j].Coords.attrib['points']   -> coordinates of this line (1) (2)
                                            .BaseLine.attrib['points'] -> coordinates of this baseline (2)
                                            .TextEquiv.Unicode         -> utf-8 string of the transcription
            
            (1) Instead of .attrib['points'] you can say .values()[0].
            (2) The line is a polygon around the line of text, the BaseLine is a line below the text.
            
            You can check for the existence of attributes: if hasattr(X.Page, "TextRegion")…
            Get a list of existing attributes: X.Page.__dict__

            """
        
        endpoint = f"collections/{colId}/{docId}/{pageNr}/text"
        page_xml = self.request_endpoint(endpoint)
        return page_xml if page_xml is not None else False
        
    def upload_page_xml(self, colId, docId, pageNr, new_status, page_xml):
        """ Upload page XML data to the Transkribus server using a POST request. 
            Returns True or False.
        
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) 
            new_status -- new_status of the page. Possible values are NEW, IN_PROGRESS, DONE, FINAL, GT. 
            
            tsId = transcript ID of the last version of this transcription (int).
            After the upload Transkribus will generate a new transcription Id and save 
            the old one as the 'parentTsId' of the new transcription. """

        # Get the transcript ID of the latest transcription:
        current_transcript = self.request_endpoint(f"collections/{colId}/{docId}/{pageNr}/curr")
        if current_transcript:
            tsId = current_transcript['tsId']
        else:
            return False
        
        headers = {'Content-Type': 'text/xml'} 
        cookies = dict(JSESSIONID=self.session_id)
        params = {'status': new_status,
                  'parent': tsId,
                  'overwrite': 'false'}
        # convert the page_xml object to a pretty utf-8 string:
        data = etree.tostring(page_xml, pretty_print=True, xml_declaration=True).decode("utf-8")

        response = requests.post(self._url(f"collections/{colId}/{docId}/{pageNr}/text"), 
                                 headers=headers,
                                 params=params,
                                 cookies=cookies, 
                                 data=data)

        if response:
            print(f"Uploaded page {colId}/{docId}/{pageNr} successfully: {response.status_code}")
            print(response.content.decode(encoding="utf-8"))
            return True
        else:
            print(f"ERROR while uploading {colId}/{docId}/{pageNr}: {response.status_code}")
            print(response.content.decode(encoding="utf-8"))
            return False

    def update_page_status(self, colId, docId, pageNr, new_status):
        """ Update the status of the transcript with the transcript ID tsId with new_status.
            Returns True or False. 
            
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) 
            new_status -- new_status of the page. Possible values are NEW, IN_PROGRESS, DONE, FINAL, GT. """

        # Get the transcript ID of the latest transcription:
        current_transcript = self.request_endpoint(f"collections/{colId}/{docId}/{pageNr}/curr")
        if current_transcript:
            tsId = current_transcript['tsId']
        else:
            return False
        
        cookies = dict(JSESSIONID=self.session_id)
        params = {'status': new_status}
        
        endpoint = f"collections/{colId}/{docId}/{pageNr}/{tsId}"
        response = requests.post(self._url(endpoint),
                                 params=params,
                                 cookies=cookies)
        
        if response:
            print(f"TRANSKRIBUS: Updated status of page {pageNr} to {new_status} in collection {colId}, document {docId}.")
            print(response.content.decode(encoding="utf-8"))
            return True
        else:
            print(f"TRANSKRIBUS: ERROR: Could not update status of page {pageNr} to {new_status} in collection {colId}, document {docId}.")
            print(response.content.decode(encoding="utf-8"))
            return False

# %%
client = Transkribus_Web()
session_id = client.login("YOUR_USER_NAME", "YOUR_PASSWORD")
# Out:
# TRANSKRIBUS: User Markus Müller (XXXXX) logged in successfully.

# %%
# Get a list of all your collections:
client.get_collections()

# You could use the "request_endpoint" function to achieve the same result:
#collections = client.request_endpoint("collections/list")
# Out:
# [{'type': 'trpCollection',
#   'colId': 19831,
#   'colName': 'XYZ@example.de Collection',
#   'description': 'XYZ@example.de',
#   'crowdsourcing': False,
#   'elearning': False,
#   'pageId': 2950070,
#   'url': 'https://files.transkribus.eu/Get?id=ZGQUVERWOEJLMXKWFKGOAQMO&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=ZGQUVERWOEJLMXKWFKGOAQMO&fileType=thumb',
#   'nrOfDocuments': 14,
#   'role': 'Owner',
#   'accountingStatus': 1},
#  {'type': 'trpCollection',
#   'colId': 37299,
#   'colName': 'FerusAlpha',
#   'description': "XYZ@example.de. Transcription of John Wild's commentary on the Gospel of John.",
#   'crowdsourcing': False,
#   'elearning': False,
#   'pageId': 5263161,
#   'url': 'https://files.transkribus.eu/Get?id=IXVIHRDIUIIEPNMGCNEBPVEY&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=IXVIHRDIUIIEPNMGCNEBPVEY&fileType=thumb',
#   'nrOfDocuments': 24,
#   'role': 'Owner',
#   'accountingStatus': 1},
#  {'type': 'trpCollection',
#   'colId': 47534,
#   'colName': 'FerusBeta',
#   'description': 'created by XYZ@example.de',
#   'crowdsourcing': False,
#   'elearning': False,
#   'pageId': 12144584,
#   'url': 'https://files.transkribus.eu/Get?id=QDVPBAVYRPFVOPVTOOGIIJDO&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=QDVPBAVYRPFVOPVTOOGIIJDO&fileType=thumb',
#   'nrOfDocuments': 8,
#   'role': 'Owner',
#   'accountingStatus': 1},
#  {'type': 'trpCollection',
#   'colId': 59163,
#   'colName': 'FerusArchiv',
#   'description': 'created by XYZ@example.de',
#   'crowdsourcing': False,
#   'elearning': False,
#   'nrOfDocuments': 12,
#   'role': 'Owner',
#   'accountingStatus': 1},
#  {'type': 'trpCollection',
#   'colId': 73141,
#   'colName': 'Transkribus Spellchecker Demo',
#   'description': 'created by XYZ@example.de',
#   'crowdsourcing': False,
#   'elearning': False,
#   'nrOfDocuments': 1,
#   'role': 'Owner',
#   'accountingStatus': 1}]

# %%
# Check the output of get_collections() above,
# pick one of the collections and store its colId here:
colId = XXXXX

# Get the metadata of all the documents in this collection:
client.get_documents_in_collection(colId)
# Out:
# [{'type': 'trpDocMetadata',
#   'docId': 202832,
#   'title': 'Wild1550-Joh1,VD16W2963,Teil_2',
#   'uploadTimestamp': 1567182500354,
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 34,
#   'pageId': 8477570,
#   'url': 'https://files.transkribus.eu/Get?id=QXLZCOEWXQGNZECIZYVSMSDN&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=QXLZCOEWXQGNZECIZYVSMSDN&fileType=thumb',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_202832',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0},
#     {'colId': 59163,
#      'colName': 'FerusArchiv',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}},
#  {'type': 'trpDocMetadata',
#   'docId': 306607,
#   'title': 'Wild1550-Joh,VD16W2963,new',
#   'author': 'Johann Wild (Ferus, 1495-1554)',
#   'uploadTimestamp': 1578936446909,
#   'genre': 'Bible Commentary',
#   'scriptType': 'NORMAL_LONG_S',
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 115,
#   'pageId': 12144528,
#   'url': 'https://files.transkribus.eu/Get?id=BTPQZEZUHUHSFJIKAPCVZDKI&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=BTPQZEZUHUHSFJIKAPCVZDKI&fileType=thumb',
#   'externalId': 'NA',
#   'authority': 'NA',
#   'language': 'Latin',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_306607',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}},
#  {'type': 'trpDocMetadata',
#   'docId': 306608,
#   'title': 'Wild1559o-Mt,Mainz,BW',
#   'uploadTimestamp': 1578936454500,
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 24,
#   'pageId': 12144537,
#   'url': 'https://files.transkribus.eu/Get?id=LYGZFELUMETPKPJMIBTUPKMS&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=LYGZFELUMETPKPJMIBTUPKMS&fileType=thumb',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_306608',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}},
#  {'type': 'trpDocMetadata',
#   'docId': 306609,
#   'title': 'Wild1559p-Mt,Paris,exp,COLOR,tom1u2',
#   'uploadTimestamp': 1578936467971,
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 11,
#   'pageId': 12144568,
#   'url': 'https://files.transkribus.eu/Get?id=QVWQWBVOXWWOLIHWEWDDZWWO&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=QVWQWBVOXWWOLIHWEWDDZWWO&fileType=thumb',
#   'externalId': 'NA',
#   'authority': 'NA',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_306609',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0},
#     {'colId': 73141,
#      'colName': 'Transkribus Spellchecker Demo',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}},
#  {'type': 'trpDocMetadata',
#   'docId': 306610,
#   'title': 'Wild1577b-Mt,Rom,COLOR',
#   'uploadTimestamp': 1578936489293,
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 26,
#   'pageId': 12144621,
#   'url': 'https://files.transkribus.eu/Get?id=KGKKTVRJRYUJGMVNQOMPPLGS&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=KGKKTVRJRYUJGMVNQOMPPLGS&fileType=thumb',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_306610',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}},
#  {'type': 'trpDocMetadata',
#   'docId': 306611,
#   'title': 'Wild1577-Joh,Rom,exp,COLOR',
#   'uploadTimestamp': 1578936520479,
#   'scriptType': 'NORMAL_LONG_S',
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 40,
#   'pageId': 12144689,
#   'url': 'https://files.transkribus.eu/Get?id=XUFKHBPXUSAMVARNHUCKMDOM&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XUFKHBPXUSAMVARNHUCKMDOM&fileType=thumb',
#   'externalId': 'NA',
#   'authority': 'NA',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_306611',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}},
#  {'type': 'trpDocMetadata',
#   'docId': 316064,
#   'title': 'Wild1578-Joh,Alcala,COLOR',
#   'uploadTimestamp': 1580315923932,
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 61,
#   'pageId': 12485790,
#   'url': 'https://files.transkribus.eu/Get?id=QTEUMDCWYUROCPBSMPYIHPJH&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=QTEUMDCWYUROCPBSMPYIHPJH&fileType=thumb',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_316064',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}},
#  {'type': 'trpDocMetadata',
#   'docId': 316069,
#   'title': 'Wild1567n-Mt,Alcala,COLOR',
#   'uploadTimestamp': 1580316183491,
#   'uploader': 'XYZ@example.de',
#   'uploaderId': XXXXX,
#   'nrOfPages': 74,
#   'pageId': 12485894,
#   'url': 'https://files.transkribus.eu/Get?id=YLATTSQFKDJZPBKCSKWQCMNA&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=YLATTSQFKDJZPBKCSKWQCMNA&fileType=thumb',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_316069',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 47534,
#      'colName': 'FerusBeta',
#      'description': 'created by XYZ@example.de',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]}}]

# %%
# Pick a document and store its docId here:
docId = XXXXXX

# Get the metadata of all the pages in this document:
client.get_pages_in_document(colId, docId)

# The same as:
#client.request_endpoint(f"collections/{colId}/{docId}/pages")
# Out:
# [{'pageId': 12144537,
#   'docId': 306608,
#   'pageNr': 1,
#   'key': 'LYGZFELUMETPKPJMIBTUPKMS',
#   'imageId': 8478757,
#   'url': 'https://files.transkribus.eu/Get?id=LYGZFELUMETPKPJMIBTUPKMS&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=LYGZFELUMETPKPJMIBTUPKMS&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0011.png',
#   'tsList': {'transcripts': [{'tsId': 33934402,
#      'parentTsId': 27409630,
#      'key': 'PNGFVQCMUUKHJPSFCVEHGQJZ',
#      'pageId': 12144537,
#      'docId': 306608,
#      'pageNr': 1,
#      'url': 'https://files.transkribus.eu/Get?id=PNGFVQCMUUKHJPSFCVEHGQJZ',
#      'status': 'FINAL',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1594302136870,
#      'md5Sum': '',
#      'nrOfRegions': 3,
#      'nrOfTranscribedRegions': 3,
#      'nrOfWordsInRegions': 390,
#      'nrOfLines': 57,
#      'nrOfTranscribedLines': 57,
#      'nrOfWordsInLines': 444,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3346,
#   'created': '2020-01-13T18:27:34.662+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'tagsStored': '2020-07-09T15:42:17.191+02:00'},
#  {'pageId': 12144540,
#   'docId': 306608,
#   'pageNr': 2,
#   'key': 'NZRDYZYOJROUCTIVIFQZXMZL',
#   'imageId': 8478760,
#   'url': 'https://files.transkribus.eu/Get?id=NZRDYZYOJROUCTIVIFQZXMZL&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=NZRDYZYOJROUCTIVIFQZXMZL&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0012.png',
#   'tsList': {'transcripts': [{'tsId': 33934412,
#      'parentTsId': 22292876,
#      'key': 'GDRMZSKIBDWSSBJYQWRMRQJI',
#      'pageId': 12144540,
#      'docId': 306608,
#      'pageNr': 2,
#      'url': 'https://files.transkribus.eu/Get?id=GDRMZSKIBDWSSBJYQWRMRQJI',
#      'status': 'FINAL',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1594302149011,
#      'md5Sum': '',
#      'nrOfRegions': 3,
#      'nrOfTranscribedRegions': 3,
#      'nrOfWordsInRegions': 532,
#      'nrOfLines': 77,
#      'nrOfTranscribedLines': 77,
#      'nrOfWordsInLines': 606,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3324,
#   'created': '2020-01-13T18:27:35.99+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'tagsStored': '2020-07-09T15:42:29.548+02:00'},
#  {'pageId': 12144544,
#   'docId': 306608,
#   'pageNr': 3,
#   'key': 'ZYDQUDSPGRLMHSRTGRBGIHLH',
#   'imageId': 8478764,
#   'url': 'https://files.transkribus.eu/Get?id=ZYDQUDSPGRLMHSRTGRBGIHLH&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=ZYDQUDSPGRLMHSRTGRBGIHLH&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0013.png',
#   'tsList': {'transcripts': [{'tsId': 22292879,
#      'parentTsId': -1,
#      'key': 'ZYMNIKZOJDCRREIUNDKWWMDZ',
#      'pageId': 12144544,
#      'docId': 306608,
#      'pageNr': 3,
#      'url': 'https://files.transkribus.eu/Get?id=ZYMNIKZOJDCRREIUNDKWWMDZ',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 2,
#      'nrOfWordsInRegions': 547,
#      'nrOfLines': 75,
#      'nrOfTranscribedLines': 75,
#      'nrOfWordsInLines': 618,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3317,
#   'created': '2020-01-13T18:27:37.863+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144547,
#   'docId': 306608,
#   'pageNr': 4,
#   'key': 'LDPQBGDEQOGIOAOHUKUJDSOJ',
#   'imageId': 8478767,
#   'url': 'https://files.transkribus.eu/Get?id=LDPQBGDEQOGIOAOHUKUJDSOJ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=LDPQBGDEQOGIOAOHUKUJDSOJ&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0014.png',
#   'tsList': {'transcripts': [{'tsId': 22292882,
#      'parentTsId': -1,
#      'key': 'WXZBXVQESGRKROMNNJARBMDJ',
#      'pageId': 12144547,
#      'docId': 306608,
#      'pageNr': 4,
#      'url': 'https://files.transkribus.eu/Get?id=WXZBXVQESGRKROMNNJARBMDJ',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 2,
#      'nrOfWordsInRegions': 510,
#      'nrOfLines': 66,
#      'nrOfTranscribedLines': 66,
#      'nrOfWordsInLines': 574,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3291,
#   'created': '2020-01-13T18:27:39.103+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144550,
#   'docId': 306608,
#   'pageNr': 5,
#   'key': 'DXZUMFKJMVZSHRJGJOKFHBEV',
#   'imageId': 8478770,
#   'url': 'https://files.transkribus.eu/Get?id=DXZUMFKJMVZSHRJGJOKFHBEV&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=DXZUMFKJMVZSHRJGJOKFHBEV&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0015.png',
#   'tsList': {'transcripts': [{'tsId': 22292885,
#      'parentTsId': -1,
#      'key': 'OMCZXXVGNEAHCODJHNNLXYDA',
#      'pageId': 12144550,
#      'docId': 306608,
#      'pageNr': 5,
#      'url': 'https://files.transkribus.eu/Get?id=OMCZXXVGNEAHCODJHNNLXYDA',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 2,
#      'nrOfWordsInRegions': 506,
#      'nrOfLines': 88,
#      'nrOfTranscribedLines': 88,
#      'nrOfWordsInLines': 592,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3298,
#   'created': '2020-01-13T18:27:40.317+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144553,
#   'docId': 306608,
#   'pageNr': 6,
#   'key': 'YYVGFOIYKGQSYKTOXCKSDBVI',
#   'imageId': 8478773,
#   'url': 'https://files.transkribus.eu/Get?id=YYVGFOIYKGQSYKTOXCKSDBVI&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=YYVGFOIYKGQSYKTOXCKSDBVI&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0016.png',
#   'tsList': {'transcripts': [{'tsId': 22292887,
#      'parentTsId': -1,
#      'key': 'QCKTJSXRBQDKLSSRZOWQSSKB',
#      'pageId': 12144553,
#      'docId': 306608,
#      'pageNr': 6,
#      'url': 'https://files.transkribus.eu/Get?id=QCKTJSXRBQDKLSSRZOWQSSKB',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 2,
#      'nrOfWordsInRegions': 523,
#      'nrOfLines': 80,
#      'nrOfTranscribedLines': 80,
#      'nrOfWordsInLines': 601,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3282,
#   'created': '2020-01-13T18:27:41.396+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144554,
#   'docId': 306608,
#   'pageNr': 7,
#   'key': 'CSOYCQDJNBMYEWRCUIGHPZKU',
#   'imageId': 8478774,
#   'url': 'https://files.transkribus.eu/Get?id=CSOYCQDJNBMYEWRCUIGHPZKU&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=CSOYCQDJNBMYEWRCUIGHPZKU&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0017.png',
#   'tsList': {'transcripts': [{'tsId': 22292890,
#      'parentTsId': -1,
#      'key': 'LPHYYXMFSDCGVDFAAPMSGMMG',
#      'pageId': 12144554,
#      'docId': 306608,
#      'pageNr': 7,
#      'url': 'https://files.transkribus.eu/Get?id=LPHYYXMFSDCGVDFAAPMSGMMG',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3319,
#   'created': '2020-01-13T18:27:42.494+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144557,
#   'docId': 306608,
#   'pageNr': 8,
#   'key': 'PERAHNQJPAPJBLKCYXLOIAVB',
#   'imageId': 8478777,
#   'url': 'https://files.transkribus.eu/Get?id=PERAHNQJPAPJBLKCYXLOIAVB&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=PERAHNQJPAPJBLKCYXLOIAVB&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0018.png',
#   'tsList': {'transcripts': [{'tsId': 22292893,
#      'parentTsId': -1,
#      'key': 'AXASPIHJLVHTQIHDOLMHDDSB',
#      'pageId': 12144557,
#      'docId': 306608,
#      'pageNr': 8,
#      'url': 'https://files.transkribus.eu/Get?id=AXASPIHJLVHTQIHDOLMHDDSB',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3322,
#   'created': '2020-01-13T18:27:43.582+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144560,
#   'docId': 306608,
#   'pageNr': 9,
#   'key': 'XUNKBFMRYNMUWFGHLGKQYFFJ',
#   'imageId': 8478780,
#   'url': 'https://files.transkribus.eu/Get?id=XUNKBFMRYNMUWFGHLGKQYFFJ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XUNKBFMRYNMUWFGHLGKQYFFJ&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0019.png',
#   'tsList': {'transcripts': [{'tsId': 22292895,
#      'parentTsId': -1,
#      'key': 'FZXBSSPNGYKXNCMTSWIBZFMW',
#      'pageId': 12144560,
#      'docId': 306608,
#      'pageNr': 9,
#      'url': 'https://files.transkribus.eu/Get?id=FZXBSSPNGYKXNCMTSWIBZFMW',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 4,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3333,
#   'created': '2020-01-13T18:27:44.593+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144562,
#   'docId': 306608,
#   'pageNr': 10,
#   'key': 'PBIAVBGRPFHNPKVSMHJPPYBD',
#   'imageId': 8478782,
#   'url': 'https://files.transkribus.eu/Get?id=PBIAVBGRPFHNPKVSMHJPPYBD&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=PBIAVBGRPFHNPKVSMHJPPYBD&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0020.png',
#   'tsList': {'transcripts': [{'tsId': 22292898,
#      'parentTsId': -1,
#      'key': 'LZUDZZXSBOAPDEVKQCUVSIKB',
#      'pageId': 12144562,
#      'docId': 306608,
#      'pageNr': 10,
#      'url': 'https://files.transkribus.eu/Get?id=LZUDZZXSBOAPDEVKQCUVSIKB',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3263,
#   'created': '2020-01-13T18:27:45.568+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144565,
#   'docId': 306608,
#   'pageNr': 11,
#   'key': 'XIUTWJYHHWWBOLCRLKGXJYQE',
#   'imageId': 8478785,
#   'url': 'https://files.transkribus.eu/Get?id=XIUTWJYHHWWBOLCRLKGXJYQE&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XIUTWJYHHWWBOLCRLKGXJYQE&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0021.png',
#   'tsList': {'transcripts': [{'tsId': 22292901,
#      'parentTsId': -1,
#      'key': 'LUPIEMCMWSAHIFGFFKXBVHLD',
#      'pageId': 12144565,
#      'docId': 306608,
#      'pageNr': 11,
#      'url': 'https://files.transkribus.eu/Get?id=LUPIEMCMWSAHIFGFFKXBVHLD',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3313,
#   'created': '2020-01-13T18:27:46.936+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144569,
#   'docId': 306608,
#   'pageNr': 12,
#   'key': 'HTQGXXLPDJVQDSEJXSCBAWHG',
#   'imageId': 8478789,
#   'url': 'https://files.transkribus.eu/Get?id=HTQGXXLPDJVQDSEJXSCBAWHG&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=HTQGXXLPDJVQDSEJXSCBAWHG&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0022.png',
#   'tsList': {'transcripts': [{'tsId': 22292906,
#      'parentTsId': -1,
#      'key': 'OYCQFNHTMXWUGDQVGNJFGGQG',
#      'pageId': 12144569,
#      'docId': 306608,
#      'pageNr': 12,
#      'url': 'https://files.transkribus.eu/Get?id=OYCQFNHTMXWUGDQVGNJFGGQG',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3259,
#   'created': '2020-01-13T18:27:48.379+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144574,
#   'docId': 306608,
#   'pageNr': 13,
#   'key': 'XEYLZTHPERGCEREIFXYNMMZT',
#   'imageId': 8478794,
#   'url': 'https://files.transkribus.eu/Get?id=XEYLZTHPERGCEREIFXYNMMZT&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XEYLZTHPERGCEREIFXYNMMZT&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0164.png',
#   'tsList': {'transcripts': [{'tsId': 22292909,
#      'parentTsId': -1,
#      'key': 'ENMYEEXHNIQEKDIXMLIXDCTE',
#      'pageId': 12144574,
#      'docId': 306608,
#      'pageNr': 13,
#      'url': 'https://files.transkribus.eu/Get?id=ENMYEEXHNIQEKDIXMLIXDCTE',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 5,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3370,
#   'created': '2020-01-13T18:27:49.722+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144577,
#   'docId': 306608,
#   'pageNr': 14,
#   'key': 'CVTBHCFKVNIRMUWIHYDQHPKS',
#   'imageId': 8478797,
#   'url': 'https://files.transkribus.eu/Get?id=CVTBHCFKVNIRMUWIHYDQHPKS&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=CVTBHCFKVNIRMUWIHYDQHPKS&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0165.png',
#   'tsList': {'transcripts': [{'tsId': 22292914,
#      'parentTsId': -1,
#      'key': 'ANPZKBYDIAUZVOKCXIUDWLFK',
#      'pageId': 12144577,
#      'docId': 306608,
#      'pageNr': 14,
#      'url': 'https://files.transkribus.eu/Get?id=ANPZKBYDIAUZVOKCXIUDWLFK',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3443,
#   'created': '2020-01-13T18:27:50.871+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144582,
#   'docId': 306608,
#   'pageNr': 15,
#   'key': 'CDXFNWFWTYPYFMUDHJUTKWNO',
#   'imageId': 8478802,
#   'url': 'https://files.transkribus.eu/Get?id=CDXFNWFWTYPYFMUDHJUTKWNO&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=CDXFNWFWTYPYFMUDHJUTKWNO&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0166.png',
#   'tsList': {'transcripts': [{'tsId': 22292917,
#      'parentTsId': -1,
#      'key': 'HGTCLIKDFYFUKADXCFMTOCFT',
#      'pageId': 12144582,
#      'docId': 306608,
#      'pageNr': 15,
#      'url': 'https://files.transkribus.eu/Get?id=HGTCLIKDFYFUKADXCFMTOCFT',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3358,
#   'created': '2020-01-13T18:27:51.962+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144585,
#   'docId': 306608,
#   'pageNr': 16,
#   'key': 'TBXRZGIADLTIBHWEACIODWSU',
#   'imageId': 8478805,
#   'url': 'https://files.transkribus.eu/Get?id=TBXRZGIADLTIBHWEACIODWSU&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=TBXRZGIADLTIBHWEACIODWSU&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0167.png',
#   'tsList': {'transcripts': [{'tsId': 22292921,
#      'parentTsId': -1,
#      'key': 'JAAHQMNJMQRNNIDTWQPRGYGZ',
#      'pageId': 12144585,
#      'docId': 306608,
#      'pageNr': 16,
#      'url': 'https://files.transkribus.eu/Get?id=JAAHQMNJMQRNNIDTWQPRGYGZ',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3445,
#   'created': '2020-01-13T18:27:53.016+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144589,
#   'docId': 306608,
#   'pageNr': 17,
#   'key': 'NGSRXQHWERACOEHJQSWATWHX',
#   'imageId': 8478809,
#   'url': 'https://files.transkribus.eu/Get?id=NGSRXQHWERACOEHJQSWATWHX&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=NGSRXQHWERACOEHJQSWATWHX&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0168.png',
#   'tsList': {'transcripts': [{'tsId': 22292925,
#      'parentTsId': -1,
#      'key': 'MKTWREXNSLFLHYHVUHCFRHQU',
#      'pageId': 12144589,
#      'docId': 306608,
#      'pageNr': 17,
#      'url': 'https://files.transkribus.eu/Get?id=MKTWREXNSLFLHYHVUHCFRHQU',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3364,
#   'created': '2020-01-13T18:27:54.232+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144593,
#   'docId': 306608,
#   'pageNr': 18,
#   'key': 'IZFTTWXXUNZGWYGYOKBBXCVZ',
#   'imageId': 8478813,
#   'url': 'https://files.transkribus.eu/Get?id=IZFTTWXXUNZGWYGYOKBBXCVZ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=IZFTTWXXUNZGWYGYOKBBXCVZ&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0169.png',
#   'tsList': {'transcripts': [{'tsId': 22292930,
#      'parentTsId': -1,
#      'key': 'ZLNLJCQHTFEKYQCARGVSKGNO',
#      'pageId': 12144593,
#      'docId': 306608,
#      'pageNr': 18,
#      'url': 'https://files.transkribus.eu/Get?id=ZLNLJCQHTFEKYQCARGVSKGNO',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3343,
#   'created': '2020-01-13T18:27:55.301+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144598,
#   'docId': 306608,
#   'pageNr': 19,
#   'key': 'YQDRIBBMZSNNKYXYERTEWXXR',
#   'imageId': 8478818,
#   'url': 'https://files.transkribus.eu/Get?id=YQDRIBBMZSNNKYXYERTEWXXR&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=YQDRIBBMZSNNKYXYERTEWXXR&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0170.png',
#   'tsList': {'transcripts': [{'tsId': 22292933,
#      'parentTsId': -1,
#      'key': 'NDHQHLDPYUZFUKJAMNICCGRM',
#      'pageId': 12144598,
#      'docId': 306608,
#      'pageNr': 19,
#      'url': 'https://files.transkribus.eu/Get?id=NDHQHLDPYUZFUKJAMNICCGRM',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3365,
#   'created': '2020-01-13T18:27:56.572+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144601,
#   'docId': 306608,
#   'pageNr': 20,
#   'key': 'GNXEWTQXKUYMCDWBBJDAPVRU',
#   'imageId': 8478821,
#   'url': 'https://files.transkribus.eu/Get?id=GNXEWTQXKUYMCDWBBJDAPVRU&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=GNXEWTQXKUYMCDWBBJDAPVRU&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0171.png',
#   'tsList': {'transcripts': [{'tsId': 22292936,
#      'parentTsId': -1,
#      'key': 'JKHUYORFPWTYWBLRWFRAWOWF',
#      'pageId': 12144601,
#      'docId': 306608,
#      'pageNr': 20,
#      'url': 'https://files.transkribus.eu/Get?id=JKHUYORFPWTYWBLRWFRAWOWF',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3309,
#   'created': '2020-01-13T18:27:57.601+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144603,
#   'docId': 306608,
#   'pageNr': 21,
#   'key': 'MTXHMHWPSCSJXJDQJRHTTMMI',
#   'imageId': 8478823,
#   'url': 'https://files.transkribus.eu/Get?id=MTXHMHWPSCSJXJDQJRHTTMMI&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=MTXHMHWPSCSJXJDQJRHTTMMI&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0172.png',
#   'tsList': {'transcripts': [{'tsId': 22292940,
#      'parentTsId': -1,
#      'key': 'ODRMTDJLPNGPCVENQFSXDUVR',
#      'pageId': 12144603,
#      'docId': 306608,
#      'pageNr': 21,
#      'url': 'https://files.transkribus.eu/Get?id=ODRMTDJLPNGPCVENQFSXDUVR',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3377,
#   'created': '2020-01-13T18:27:58.605+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144607,
#   'docId': 306608,
#   'pageNr': 22,
#   'key': 'BVMLHNVFJYILBFGPHKBRPQMT',
#   'imageId': 8478827,
#   'url': 'https://files.transkribus.eu/Get?id=BVMLHNVFJYILBFGPHKBRPQMT&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=BVMLHNVFJYILBFGPHKBRPQMT&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0173.png',
#   'tsList': {'transcripts': [{'tsId': 22292944,
#      'parentTsId': -1,
#      'key': 'IWUTORMOWFZSQPUKVGFFKKMY',
#      'pageId': 12144607,
#      'docId': 306608,
#      'pageNr': 22,
#      'url': 'https://files.transkribus.eu/Get?id=IWUTORMOWFZSQPUKVGFFKKMY',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3404,
#   'created': '2020-01-13T18:28:00.655+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144610,
#   'docId': 306608,
#   'pageNr': 23,
#   'key': 'ZRTRVCJBHNJNQYQRIJNLHXCW',
#   'imageId': 8478830,
#   'url': 'https://files.transkribus.eu/Get?id=ZRTRVCJBHNJNQYQRIJNLHXCW&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=ZRTRVCJBHNJNQYQRIJNLHXCW&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0174.png',
#   'tsList': {'transcripts': [{'tsId': 22292946,
#      'parentTsId': -1,
#      'key': 'IHHBCHOYFYBHULTZLEJOAECF',
#      'pageId': 12144610,
#      'docId': 306608,
#      'pageNr': 23,
#      'url': 'https://files.transkribus.eu/Get?id=IHHBCHOYFYBHULTZLEJOAECF',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3399,
#   'created': '2020-01-13T18:28:01.894+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}},
#  {'pageId': 12144612,
#   'docId': 306608,
#   'pageNr': 24,
#   'key': 'DAIOBQISXIPOFUROSAMPNLDL',
#   'imageId': 8478832,
#   'url': 'https://files.transkribus.eu/Get?id=DAIOBQISXIPOFUROSAMPNLDL&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=DAIOBQISXIPOFUROSAMPNLDL&fileType=thumb',
#   'imgFileName': 'Wild1559o-Mt,Mainz,BW,VD16W2965,__0175.png',
#   'tsList': {'transcripts': [{'tsId': 22292949,
#      'parentTsId': -1,
#      'key': 'VUWVRKARQERFCZKWHUBBKIWM',
#      'pageId': 12144612,
#      'docId': 306608,
#      'pageNr': 24,
#      'url': 'https://files.transkribus.eu/Get?id=VUWVRKARQERFCZKWHUBBKIWM',
#      'status': 'NEW',
#      'userName': 'XYZ@example.de',
#      'userId': XXXXX,
#      'timestamp': 1578936454500,
#      'md5Sum': '',
#      'nrOfRegions': 2,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0}]},
#   'width': 2085,
#   'height': 3395,
#   'created': '2020-01-13T18:28:03.126+01:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []}}]

# %%
# Pick a page and store its pageNr here:
pageNr = XX

# Let's check the Id of the last transcript:
client.request_endpoint(f"collections/{colId}/{docId}/{pageNr}/curr")['tsId']
# Out:
# 33934412

# %%
# Get the page_xml data of this page:
doc = client.get_page_xml(colId, docId, pageNr)

# Same as:
#doc = client.request_endpoint(f"collections/{colId}/{docId}/{pageNr}/text")

# %%
# Let's play around with the page_xml object:
# (Comment out and run one of the following lines. You may have to modify the indices of the dicts)

#doc.Page.TextRegion[1].TextLine[1].Coords.values()
#doc.Page.TextRegion[1].TextEquiv.Unicode
#dir(doc.Metadata)
#print(etree.tostring(doc, pretty_print=True, xml_declaration=True).decode("utf-8"))
# Out:
# <?xml version='1.0' encoding='ASCII'?>
# <PcGts xmlns="http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15 http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15/pagecontent.xsd">
#   <Metadata>
#     <Creator>prov=University of Rostock/Institute of Mathematics/CITlab/Gundram Leifert/gundram.leifert@uni-rostock.de:name=Printed-Wild1550-In_Ioannem-VD16W2963(htr_id=16391)::::v=2.4.2
# prov=University of Rostock/Institute of Mathematics/CITlab/Tobias Gruening/tobias.gruening@uni-rostock.de:name=de.uros.citlab.module.baseline2polygon.B2PSeamMultiOriented:v=2.4.2
# prov=University of Rostock/Institute of Mathematics/CITlab/Tobias Gruening/tobias.gruening@uni-rostock.de:name=/net_tf/LA73_249_0mod360.pb:de.uros.citlab.segmentation.CITlab_LA_ML:v=2.4.2
# TRP</Creator>
#     <Created>2019-08-30T18:27:41.219+02:00</Created>
#     <LastChange>2021-05-26T21:45:44.392+02:00</LastChange>
#   </Metadata>
#   <Page imageFilename="Wild1550-Joh1,VD16W2963,Teil_2-0002.jpg" imageWidth="6250" imageHeight="10462">
#     <ReadingOrder>
#       <OrderedGroup id="ro_1622058344406" caption="Regions reading order">
#         <RegionRefIndexed index="0" regionRef="region_1576767831637_45"/>
#         <RegionRefIndexed index="1" regionRef="r2"/>
#       </OrderedGroup>
#     </ReadingOrder>
#     <TextRegion type="marginalia" id="region_1576767831637_45" custom="readingOrder {index:0;} structure {type:marginalia;}">
#       <Coords points="820,1608 1397,1608 1397,2893 820,2893"/>
#     </TextRegion>
#     <TextRegion orientation="0.0" type="paragraph" id="r2" custom="readingOrder {index:1;} structure {type:paragraph;}">
#       <Coords points="1426,747 1373,8942 5723,8863 5744,677"/>
#       <TextLine id="r2l1" custom="readingOrder {index:0;}">
#         <Baseline points="5240,8812 5266,8814 5292,8816 5319,8817 5345,8817 5371,8817 5398,8817 5424,8817 5450,8816 5477,8816 5503,8816 5530,8818"/>
#         <TextEquiv>
#           <Unicode>po&#383;&#383;e&#383;</Unicode>
#         </TextEquiv>
#       </TextLine>
#       <TextEquiv>
#         <Unicode>TIONE
# NoO.
# AN
# s, qui onere leg
# , &#224; quo mitiora &#383;perat
# hoc e&#383;t, alium quempia
# Demum ad Ioan-
# nos liberet, &amp; carnaliter &#383;ecuros faciat, &amp;c&#772;.
# ore Ioannis (nam &amp; ip&#383;um uidebant contra-
# nem mittunt, non a
# rium &#383;uis affectibus) &#383;ed odio &amp; inuidia Chri&#383;ti, ut &#383;i hunc hono-
# rem Ioannes agno&#383;ceret, haberent iu&#383;tam occa&#383;ionem in Chri&#383;tur
# Ioan. 5. &#383;&#281;uiendi, &amp; doctrinam eius damnandi. Hinc ip&#383;e Chri&#383;tus dicit:
# Vos mi&#383;i&#383;tis ad Ioannem, &amp; uolui&#383;tis ad tempus exultare in luce
# i&#383;tis eo interin
# eius, id e&#383;t, obtuli&#383;tis ei honorem Me&#383;si&#230;, &amp; uo
# Huc pertinet, quod Chri=
# primeretis me, &amp;c&#772;.
# abuti, donec o
# &#383;tus de &#383;eip&#383;o &#383;ub parabola nobilis cuiu&#383;dam, qui peregre profectus,
# t, eius ode-
# s, inq&#658;
# n quoddam &#383;ibi &#383;ubijcere uolebat.
# Luc. 19. Regni
# s hunc re-
# rant eum, &amp; legationem mi&#383;erunt, dicentes: Nolum
# ere mundi inge
# Ex his igitur &#383;atis
# gnare &#383;uper nos, &amp;c&#772;.
# nium arbitror.
# non negauit &amp;c. ]
# 	E	t confe&#383;&#383;us est, 6
# m, &#383;ed
# Hoc e&#383;t, non retractauit te&#383;timonium antea Chri&#383;to di
# ingenue rur&#383;us Chri&#383;to &#383;uam authoritatem a&#383;&#383;eruit. Item confe&#383;&#383;u
# e&#383;t, &#383;e non e&#383;&#383;e, quod non erat, &amp; non negauit, &#383;e e&#383;&#383;e quod erat.
# ui negant &#383;e e&#383;&#383;e, quod &#383;unt, hoc e&#383;t,
# Contrarium faciunt im
# ij, c
# nolunt uideri peccatores, &amp; fatentur, &#383;ibiq&#658; ip&#383;is a&#383;&#383;cribunt, quod
# e autem dixit:
# ulant &#383;e &#383;anctos. Affirmatiu
# non &#383;unt, hoc e&#383;t, &#383;i
# Confessus est, cum apertius dicere potuerit: Negauit &#383;e e&#383;&#383;e Chri-
# &#383;tum. Sed hoc &#383;ignificantius e&#383;t, quia uolebant Phari&#383;&#230;i, ut totan
# pr&#230;dicationem retractaret. Ideo ait: Confes&#383;us est, hoc e&#383;t, con&#383;tan-
# ter confe&#383;&#383;us e&#383;t uerbum &#383;uum. Pr&#230;terea eandem &#383;ententiam
# tertio repetit: Confe&#383;&#383;us est, Non negauit, Confe&#383;&#383;us est. Hoc auten
# ideo fecit. Primo, ut inculcet &amp; exprobret Iud&#230;is incredulis &#383;u
# i-
# impietatem, qui omnes Ioannem uelut uirum Dei &#383;anctum &#383;
# m fe-
# piebant, noluerint tamen ei credere, de Chri&#383;to te&#383;timoni
# renti. Secundo, ut pios Iud&#230;os in fide Chri&#383;ti contineat, nihi
# deterritos Phari&#383;&#230;orum per&#383;ecutione, qua Chri&#383;tum per&#383;ecuti &#383;unt:
# Qua&#383;i dicat, S&#230;uiant illi quantumcunq&#658; uelint, uobis &#383;atis &#383;it, quod
# Ioannes ille Bapti&#383;ta, quem &#383;uo ip&#383;orum te&#383;timonio tanquam Pro-
# phetam uenerabantur, clari&#383;sime te&#383;tatus e&#383;t, hunc e&#383;&#383;e uerum Me&#383;-
# Tertio, per hoc nobis uoluit in&#383;ignem Ioannis con&#383;tan-
# &#383;iam.
# m habeat
# tiam ob oculos ponere. Fortem enim &amp; inuictum an
# nece&#383;&#383;e e&#383;t, qui fauorem &amp; odium hominum &#230;que contemnit, quiq&#658;
# nec promi&#383;sis nec minis, &#224; ueritate abducitur. Quis e&#383;t hic, &amp;l
# dabimus eum? Rara e&#383;t huiu&#383;modi con&#383;tantia. Atqui Ioannes
# poterat uno uerbo omnium potentium fauorem mereri, &amp; magna
# uitare pericula. Nihilominus tamen in ueritate per&#383;titit, quamui
# m &#383;ibi authoritatis hacten
# non ignorabat, rem hanc non &#383;
# po&#383;&#383;e&#383;</Unicode>
#       </TextEquiv>
#     </TextRegion>
#   </Page>
# </PcGts>

# %% [markdown]
# ## Additional functions
# Having tested the `Transkribus_Web` class, we should build some additional functions that help us to deal with the data downloaded from Transkribus. The following code makes use of the [XPath](https://www.w3schools.com/xml/xml_xpath.asp) standard of XML. (The `find` method of the `objectify` API of `lxml` can understand XPath.)

# %%
def check_page(page_xml):
    """ Make sure that the page_xml contains
        – TextRegions
        – Baselines
        – TextEquiv, i.e. actual text in the lines. 
        This is useful for further processing of the data to prevent crashes.
        
        page_xml -- a lxml.objectify object of a page in Transkribus """
        
    ns = "{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}"
    
    if page_xml.find(f".//{ns}TextRegion") is None:
        return "PAGE-XML: ERROR: No TextRegions found."
    if page_xml.find(f".//{ns}Baseline") is None:
        return "PAGE-XML: ERROR: No BaseLines found."
    if page_xml.find(f".//{ns}TextEquiv") is None:
        return "PAGE-XML: ERROR: Lines contain no text."

    return True

check_page(doc)
# Out:
# True

# %% [markdown]
# The `page_xml` contains a lot of data and metadata. For us, the most interesting pieces are the lines containing the actual transcription. Since every line has a line number and is part of a TextRegion which also has a number, it is convenient to write a function that extracts these attributes:

# %%
import re

def get_custom_attributes(string):
    custom_attributes = re.compile(r'\{(\w*?):(\w*?);\}')
    return dict(custom_attributes.findall(string))

# Store the namespace string used by the Transkribus page_xml format:
ns = "{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15
# r2l55 deterritos Phariſæorum perſecutione, qua Chriſtum perſecuti ſunt:
# r2l56 Quaſi dicat, Sæuiant illi quantumcunqʒ uelint, uobis ſatis ſit, quod
# r2l57 Ioannes ille Baptiſta, quem ſuo ipſorum teſtimonio tanquam Pro-
# r2l58 phetam uenerabantur, clariſsime teſtatus eſt, hunc eſſe uerum Meſ-
# r2l59 Tertio, per hoc nobis uoluit inſignem Ioannis conſtan-
# r2l60 ſiam.
# r2l61 m habeat
# r2l62 tiam ob oculos ponere. Fortem enim & inuictum an
# r2l63 neceſſe eſt, qui fauorem & odium hominum æque contemnit, quiqʒ
# r2l64 nec promiſsis nec minis, à ueritate abducitur. Quis eſt hic, &l
# r2l65 dabimus eum? Rara eſt huiuſmodi conſtantia. Atqui Ioannes
# r2l66 poterat uno uerbo omnium potentium fauorem mereri, & magna
# r2l67 uitare pericula. Nihilominus tamen in ueritate perſtitit, quamui
# r2l68 m ſibi authoritatis hacten
# r2l69 non ignorabat, rem hanc non ſ
# r2l70 poſſeſ

# %% [markdown]
# Oh my God, there are so many transcription errors on this page!! The following snippet shows how to manipulate a line in the transcription:

# %%
# print the first line:
print(doc.Page.TextRegion[1].TextLine[0].TextEquiv.Unicode)
# modify the first line:
doc.Page.TextRegion[1].TextLine[0].TextEquiv.Unicode = "TIONE"
# print the first line:
print(doc.Page.TextRegion[1].TextLine[0].TextEquiv.Unicode)
# Out:
# tet. Ad vltimum, quem Chriſtum audire piget, is nec me aliud loquentem au-
# TIONE

# %% [markdown]
# If you upload the manipulated transcription, the changes you made in the previous step will be stored on the Transkribus server:

# %%
client.upload_page_xml(colId, docId, pageNr, "GT", doc)

# "GT" means "Ground Truth" and is the status of the page. 
# Possible statuses are: "NEW", "IN_PROGRESS", "DONE", "FINAL", "GT"
# Out:
# Uploaded page 47534/202832/2 successfully: 200
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><trpTranscriptMetadata><tsId>58367253</tsId><parentTsId>58367242</parentTsId><key>WWWVWDDMJHDPDMHWDRAAHNKM</key><pageId>8477571</pageId><docId>202832</docId><pageNr>2</pageNr><url>https://files.transkribus.eu/Get?id=WWWVWDDMJHDPDMHWDRAAHNKM</url><status>GT</status><userName>XYZ@example.de</userName><userId>XXXXX</userId><timestamp>1622058344411</timestamp><md5Sum></md5Sum><nrOfRegions>2</nrOfRegions><nrOfTranscribedRegions>1</nrOfTranscribedRegions><nrOfWordsInRegions>352</nrOfWordsInRegions><nrOfLines>70</nrOfLines><nrOfTranscribedLines>70</nrOfTranscribedLines><nrOfWordsInLines>420</nrOfWordsInLines><nrOfWords>0</nrOfWords><nrOfTranscribedWords>0</nrOfTranscribedWords></trpTranscriptMetadata>
# True

# %% [markdown]
# Another frequent operaion is to update the status of a page:

# %%
# Change the status of the page (but nothing else):
client.update_page_status(47534, 202832, 2, "GT")
# Out:
# TRANSKRIBUS: Updated status of page 2 to GT in collection 47534, document 202832.
# True

# %% [markdown]
# ## Log Out
# Last but not least, we should always log out in the end…

# %%
# … and finally, log out:
client.logout()
# Out:
# TRANSKRIBUS: Logged out successfully.
# True
